# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/leaderboards.csv', index_col=1)
df.index = pd.to_datetime(df.index)

# %%
df
# Out:
#                           leaderboard  tier  score
# timestamp
# 2019-05-06 11:44:29+00:00     leagues     0  906.0
# 2019-05-13 17:27:48+00:00     leagues     1  848.0
# 2019-05-20 20:50:44+00:00     leagues     2  675.0
# 2019-05-27 06:35:40+00:00     leagues     3  633.0
# 2019-06-03 08:58:33+00:00     leagues     3  499.0
# ...                               ...   ...    ...
# 2022-06-27 05:44:45+00:00     leagues     7  443.0
# 2022-07-04 05:35:36+00:00     leagues     8  366.0
# 2022-07-11 05:50:23+00:00     leagues     8  315.0
# 2022-07-18 05:58:14+00:00     leagues     8  375.0
# 2022-07-25 06:05:05+00:00     leagues     8  276.0
#
# [169 rows x 3 columns]

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))
ax[0].hist(df['score'], bins=20, density=True)
ax[1].plot(df['score'])

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))
sns.countplot(data=df, x='tier', ax=ax[0])
ax[1].plot(df['tier'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
h = ax.hist2d(df['tier'], df['score'], bins=[len(df['tier'].unique()), 20])
fig.colorbar(h[3], ax=ax)
ax.set_ylabel('Score')
ax.set_xlabel('Tier')
# Out:
# Text(0.5, 0, 'Tier')
